# %%
import pandas as pd

# %matplotlib inline

import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default')
pd.set_option('display.width', 5000) 
plt.rcParams['figure.figsize'] = (15, 8)
pd.set_option('display.max_columns', 60)

# %%
lab3_b = pd.read_csv("lab3_plots_b.txt")
lab3p = lab3_b.plot(x='b', y='map', legend=False)
lab3p.set_ylabel("map")

# %%
lab3_k = pd.read_csv("lab3_plots_k.txt")
lab3pk = lab3_k.plot(x='k1', y='map', legend=False)
lab3pk.set_ylabel("map")

# %%
lab4_R = pd.read_csv("lab4_plots_R.txt")
lab4r = lab4_R.plot(x='R', y='map', legend=False)
lab4r.set_ylabel("map")

# %%
lab4_hist = pd.read_csv("lab4_hist_map.txt")
lab4h = lab4_hist.plot(x='method', y='map', kind='bar', legend=False)
lab4h.set_ylim((0.24, 0.25))
lab4h.set_ylabel("map")

# %%
lab5_a = pd.read_csv("lab5_plots_alpha.txt")
lab5a = lab5_a.plot(x='alpha', y='map', legend=False)
lab5a.set_ylabel("map")

# %%
lab6_n = pd.read_csv("lab6_plots_N.txt")
lab6n = lab6_n.plot(x='N', y='map', legend=False)
lab6n.set_ylabel("map")

# %%
lab7_n = pd.read_csv("lab7_plots_N.txt")
lab7n = lab7_n.plot(x='N', y='map', legend=False)
lab7n.set_ylabel("map")

# %%
es_lab3 = pd.read_csv("es_lab3.txt")
import numpy as np

es_lab3['iterations'] = es_lab3['iterations'].multiply(35.0)
es_lab3['baseline'] = pd.Series(np.ones(len(es_lab5))*0.2467, index=es_lab3.index)
print es_lab3.head(5)
esl3 = es_lab3.plot(x=['iterations'], y=['es', 'baseline'])
esl3.set_ylabel("MAP")
esl3.set_xlabel("function evaluations")
# Out:
#    iterations      es  baseline
# 0           0  0.0534    0.2467
# 1          35  0.1248    0.2467
# 2          70  0.2602    0.2467
# 3         105  0.2602    0.2467
# 4         140  0.2602    0.2467

# %%
es_lab5 = pd.read_csv("es_lab5.txt")
import numpy as np
es_lab5['iterations'] = es_lab5['iterations'].multiply(35.0)
es_lab5['baseline'] = pd.Series(np.ones(len(es_lab5))*0.2467, index=es_lab5.index)
es_lab5['lab3_opt'] = pd.Series(np.ones(len(es_lab5))*0.3354, index=es_lab5.index)
print es_lab5.head(5)
esl5 = es_lab5.plot(x=['iterations'], y=['es', 'baseline', 'lab3_opt'])
esl5.set_ylabel("MAP")
esl5.set_xlabel("function evaluations")
# Out:
#    iterations      es  baseline  lab3_opt
# 0           0  0.0428    0.2467    0.3354
# 1          35  0.1598    0.2467    0.3354
# 2          70  0.2509    0.2467    0.3354
# 3         105  0.3257    0.2467    0.3354
# 4         140  0.2796    0.2467    0.3354
