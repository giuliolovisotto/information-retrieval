# %%
import pandas as pd

# %matplotlib inline

import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default')
pd.set_option('display.width', 5000) 
plt.rcParams['figure.figsize'] = (15, 8)
pd.set_option('display.max_columns', 60)

# %%
lab3_b = pd.read_csv("lab3_plots_b.txt")
lab3p = lab3_b.plot(x='b', y='map', legend=False)
lab3p.set_ylabel("map")
# Out:
# /usr/lib/python2.7/site-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family [u'monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
lab3_k = pd.read_csv("lab3_plots_k.txt")
lab3pk = lab3_k.plot(x='k1', y='map', legend=False)
lab3pk.set_ylabel("map")

# %%
lab4_R = pd.read_csv("lab4_plots_R.txt")
lab4r = lab4_R.plot(x='R', y='map', linewidth=3, legend=False, color='b')
lab4r.set_ylabel("MAP", fontsize=40)
lab4r.set_xlabel("R", fontsize=30)
lab4r.tick_params(axis='both', which='major', labelsize=20)

# %%
lab4_hist = pd.read_csv("hist_map.txt")
my_colors = 'b'
lab4h = lab4_hist.plot(x='method', y='map', kind='bar', legend=False, color=my_colors)
lab4h.set_ylim((0.24, 0.35))
lab4h.set_ylabel("MAP", fontsize=40)
lab4h.set_xlabel("")
lab4h.tick_params(axis='both', which='major', labelsize=20)
xlabels = lab4h.get_xticklabels()

for label in xlabels:
    label.set_rotation(45)

# %%
lab5_a = pd.read_csv("lab5_plots_alpha.txt")
lab5a = lab5_a.plot(x='alpha', y='map', legend=False, linewidth=3, color='b')
lab5a.set_ylabel("MAP", fontsize=40)
lab5a.set_xlabel("$\\alpha$", fontsize=40)
lab5a.tick_params(axis='both', which='major', labelsize=20)

# %%
lab6_n = pd.read_csv("lab6_plots_Nd.txt")
lab6n = lab6_n.plot(x='N', y='map', legend=False, linewidth=3, color='b')
lab6n.set_ylabel("MAP", fontsize=40)
lab6n.set_xlabel("N", fontsize=40)
lab6n.tick_params(axis='both', which='major', labelsize=20)

# %%
lab7_n = pd.read_csv("lab7_plots_Nd.txt")
lab7n = lab7_n.plot(x='N', y='map', legend=False, linewidth=3, color='b')
lab7n.set_ylabel("MAP", fontsize=40)
lab7n.set_xlabel("N", fontsize=40)
lab7n.set_ylim((0.3370, 0.3411))
lab7n.tick_params(axis='both', which='major', labelsize=20)

# %%
es_lab3 = pd.read_csv("es_lab3.txt")
import numpy as np

es_lab3['iterations'] = es_lab3['iterations'].multiply(35.0)
# es_lab3['baseline'] = pd.Series(np.ones(len(es_lab3))*0.2467, index=es_lab3.index)
print es_lab3.head(5)
esl3 = es_lab3.plot(x=['iterations'], y=['lab3'], linewidth=3)
esl3.set_ylabel("MAP", fontsize=40)
esl3.set_xlabel("function evaluations", fontsize=30)
esl3.tick_params(axis='both', which='major', labelsize=20)
esl3.legend(loc=4,prop={'size':25})
# Out:
#    iterations    lab3
# 0           0  0.0534
# 1          35  0.1248
# 2          70  0.2602
# 3         105  0.2602
# 4         140  0.2602

# %%
es_lab4_e = pd.read_csv("es_lab4_esplicito.txt")
import numpy as np

es_lab4_e['iterations'] = es_lab4_e['iterations'].multiply(35.0)
print es_lab4_e.head(5)
esl4e = es_lab4_e.plot(x=['iterations'], y=['lab4_explicit'], linewidth=3)
esl4e.set_ylabel("MAP", fontsize=40)
esl4e.set_xlabel("function evaluations", fontsize=30)
esl4e.tick_params(axis='both', which='major', labelsize=20)
esl4e.legend(loc=4,prop={'size':25})
# Out:
#    iterations  lab4_explicit
# 0           0         0.0452
# 1          35         0.3009
# 2          70         0.2937
# 3         105         0.3084
# 4         140         0.3310

# %%
es_lab4_p = pd.read_csv("es_lab4_pseudo.txt")
import numpy as np
es_lab4_p['iterations'] = es_lab4_p['iterations'].multiply(35.0)
print es_lab4_p.head(5)
esl4p = es_lab4_p.plot(x=['iterations'], y=['lab4_pseudo'], linewidth=3)
esl4p.set_ylabel("MAP", fontsize=40)
esl4p.set_xlabel("function evaluations", fontsize=30)
esl4p.tick_params(axis='both', which='major', labelsize=20)
esl4p.legend(loc=4,prop={'size':25})
# Out:
#    iterations  lab4_pseudo
# 0           0       0.0382
# 1          35       0.2410
# 2          70       0.2786
# 3         105       0.2766
# 4         140       0.3020

# %%
es_lab5 = pd.read_csv("es_lab5.txt")
import numpy as np
es_lab5['iterations'] = es_lab5['iterations'].multiply(35.0)
# es_lab5['baseline'] = pd.Series(np.ones(len(es_lab5))*0.2467, index=es_lab5.index)
# es_lab5['lab3_opt'] = pd.Series(np.ones(len(es_lab5))*0.3354, index=es_lab5.index)
print es_lab5.head(5)
esl5 = es_lab5.plot(x=['iterations'], y=['lab5'], linewidth=3)
esl5.set_ylabel("MAP", fontsize=40)
esl5.set_xlabel("function evaluations", fontsize=40)
esl5.tick_params(axis='both', which='major', labelsize=20)
esl5.legend(loc=4,prop={'size':25})
# Out:
#    iterations    lab5
# 0           0  0.0428
# 1          35  0.1598
# 2          70  0.2509
# 3         105  0.3257
# 4         140  0.2796

# %%
es_lab6 = pd.read_csv("es_lab6.txt")
import numpy as np
es_lab6['iterations'] = es_lab6['iterations'].multiply(35.0)
# es_lab5['baseline'] = pd.Series(np.ones(len(es_lab5))*0.2467, index=es_lab5.index)
# es_lab5['lab3_opt'] = pd.Series(np.ones(len(es_lab5))*0.3354, index=es_lab5.index)
print es_lab6.head(5)
esl6 = es_lab6.plot(x=['iterations'], y=['lab6'], linewidth=3)
esl6.set_ylabel("MAP", fontsize=40)
esl6.set_xlabel("function evaluations", fontsize=40)
esl6.tick_params(axis='both', which='major', labelsize=20)
esl6.legend(loc=4,prop={'size':25})
# Out:
#    iterations    lab6
# 0           0  0.0563
# 1          35  0.2277
# 2          70  0.2340
# 3         105  0.2340
# 4         140  0.2340

# %%
es_lab7 = pd.read_csv("es_lab7.txt")
import numpy as np
es_lab7['iterations'] = es_lab7['iterations'].multiply(35.0)
# es_lab5['baseline'] = pd.Series(np.ones(len(es_lab5))*0.2467, index=es_lab5.index)
# es_lab5['lab3_opt'] = pd.Series(np.ones(len(es_lab5))*0.3354, index=es_lab5.index)
print es_lab7.head(5)
esl7 = es_lab7.plot(x=['iterations'], y=['lab7'], linewidth=3)
esl7.set_ylabel("MAP", fontsize=40)
esl7.set_xlabel("function evaluations", fontsize=40)
esl7.tick_params(axis='both', which='major', labelsize=20)
esl7.legend(loc=4,prop={'size':25})
# Out:
#    iterations    lab7
# 0           0  0.0540
# 1          35  0.1108
# 2          70  0.1989
# 3         105  0.2543
# 4         140  0.3250
